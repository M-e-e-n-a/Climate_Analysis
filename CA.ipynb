# %% [markdown]
# <a href="https://colab.research.google.com/github/M-e-e-n-a/Climate_Analysis/blob/main/CA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
for file in ['data11.csv', 'data22.csv','excel_file1.csv']:
  df = pd.read_csv(file, nrows=5)
  print(df)
# Out:
#           Country Total greenhouse gas emissions year 2015  \
# 0     Afghanistan                              31619.07371
# 1         Albania                              9408.765344
# 2         Algeria                              261745.2952
# 3  American Samoa                                       ..
# 4         Andorra                                579.22902
#
#   Total greenhouse gas emissions year 2020 Carbon dioxide emissions year 2015  \
# 0                              31119.04539                           10057.59
# 1                               8304.29494                               4797
# 2                              266702.6795                             156273
# 3                                       ..                                 ..
# 4                               577.573639                            465.328
#
#   Carbon dioxide emissions year 2020 Methane emissions year 2015  \
# 0                            8709.47                 15943.92618
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('excel_file1.csv')

data_sorted = data.sort_values(by='_mean', ascending=False)

# Select the top 20 countries with the highest mean temperature rise
top_20_countries = data_sorted.head(20)

# Create a bar chart to visualize the results
plt.figure(figsize=(12, 8))
plt.barh(top_20_countries['Country'], top_20_countries['_mean'], color='skyblue')
plt.xlabel('Mean Temperature Rise (°C)')
plt.ylabel('Country')
plt.title('Top 20 Countries with Highest Mean Temperature Rise')
plt.gca().invert_yaxis()  # Reverse the order to show the highest at the top
plt.show()

# %%
data1=pd.read_csv('data11.csv')
data2=pd.read_csv('data22.csv')

print(data2.keys)
# Out:
# <bound method NDFrame.keys of                                                Country  \
# 0                                          Afghanistan
# 1                                              Albania
# 2                                              Algeria
# 3                                       American Samoa
# 4                                              Andorra
# ..                                                 ...
# 297                                             Source
# 298                                                NaN
# 299  Climate Watch. 2020. GHG Emissions. Washington...
# 300                                                NaN
# 301  Please see the online table at http://wdi.worl...
#
#     Net energy imports(% of energy use) year 1990  \
# 0                                              ..
# 1                                 7.9650583526857
# 2                               -351.212563673921
# 3                                              ..
# ...

# %%
import pandas as pd
# Replace with the actual path to your cleaned data
data_mean_temp = pd.read_csv('excel_file1.csv')

# Merge Data1 and Data2 based on the common table names
merged_data = pd.merge(data1, data2, left_on=data1.columns[0], right_on=data2.columns[0], how='inner')

# Merge the merged_data with the dataset containing mean temperature rise
final_merged_data = pd.merge(merged_data, data_mean_temp, on='Country', how='inner')

# Calculate correlations with mean temperature rise
correlations = final_merged_data.corr()['_mean']

# Display correlations
print(correlations)
# Out:
# _mean    1.0
# Name: _mean, dtype: float64
# <ipython-input-40-da754c35c524>:12: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = final_merged_data.corr()['_mean']

# %%
# Calculate the correlation matrix for all variables
correlation_matrix = final_merged_data.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#        _mean
# _mean    1.0
# <ipython-input-41-29f44fe3f0f0>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = final_merged_data.corr()

# %%
correlation_matrix = final_merged_data[['_mean', 'Carbon dioxide emissions year 2015']].corr()
# Out:
# <ipython-input-47-c8f635e5ce14>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = final_merged_data[['_mean', 'Carbon dioxide emissions year 2015']].corr()

# %%
final_merged_data.columns
# Out:
# Index(['Country', 'Total greenhouse gas emissions year 2015',
#        'Total greenhouse gas emissions year 2020',
#        'Carbon dioxide emissions year 2015',
#        'Carbon dioxide emissions year 2020', 'Methane emissions year 2015',
#        'Methane emissions year 2020', 'Nitrous oxide emissions year 2015',
#        'Nitrous oxide emissions year 2020',
#        'Net energy imports(% of energy use) year 1990',
#        'Net energy imports(% of energy use) year 2015',
#        'GDP per unit of energy use(2017 PPP $ per kilogram of oil equivalent) year 1990',
#        'GDP per unit of energy use(2017 PPP $ per kilogram of oil equivalent) year 1990.1',
#        'Carbon dioxide emissions (1000 metric tons) year 2015',
#        'Carbon dioxide emissions (1000 metric tons) year 2020',
#        'Carbon intensity kilograms per kilograms of oil equivalent energy use year 1990',
#        'Carbon intensity kilograms per kilograms of oil equivalent energy use year 2014',
# ...

# %%
# Select only the numerical columns from your dataset
numerical_columns = final_merged_data.select_dtypes(include=['number'])
print(numerical_columns)
# Calculate the correlation matrix
correlation_matrix = numerical_columns.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#         _mean
# 0    2.280072
# 1    1.874529
# 2    2.341134
# 3    1.876068
# 4    1.768326
# ..        ...
# 201  1.285139
# 202  2.214564
# 203  1.183874
# 204  1.814201
# 205  1.868661
#
# [206 rows x 1 columns]
#        _mean
# _mean    1.0

# %%
final_merged_data.head()
# Out:
#        Country Total greenhouse gas emissions year 2015  \
# 0  Afghanistan                              31619.07371
# 1      Albania                              9408.765344
# 2      Algeria                              261745.2952
# 3      Andorra                                579.22902
# 4       Angola                              88673.04141
#
#   Total greenhouse gas emissions year 2020 Carbon dioxide emissions year 2015  \
# 0                              31119.04539                           10057.59
# 1                               8304.29494                               4797
# 2                              266702.6795                             156273
# 3                               577.573639                            465.328
# 4                               70781.0562                            31648.9
#
#   Carbon dioxide emissions year 2020 Methane emissions year 2015  \
# 0                            8709.47                 15943.92618
# ...

# %%
import pandas as pd
import numpy as np
# Load your dataset
data = final_merged_data

data = data.replace('..', np.nan)
# Convert columns with decimal values to numeric
decimal_columns = ['Total greenhouse gas emissions year 2015',
       'Total greenhouse gas emissions year 2020',
       'Carbon dioxide emissions year 2015',
       'Carbon dioxide emissions year 2020', 'Methane emissions year 2015',
       'Methane emissions year 2020', 'Nitrous oxide emissions year 2015',
       'Nitrous oxide emissions year 2020',
       'Net energy imports(% of energy use) year 1990',
       'Net energy imports(% of energy use) year 2015',
       'GDP per unit of energy use(2017 PPP $ per kilogram of oil equivalent) year 1990',
       'GDP per unit of energy use(2017 PPP $ per kilogram of oil equivalent) year 1990.1',
       'Carbon dioxide emissions (1000 metric tons) year 2015',
       'Carbon dioxide emissions (1000 metric tons) year 2020',
       'Carbon intensity kilograms per kilograms of oil equivalent energy use year 1990',
       'Carbon intensity kilograms per kilograms of oil equivalent energy use year 2014',
       'Per capita metric tons year 2015', 'Per capita metric tons year 2020',
       '_mean'] # Replace with the actual column names
data[decimal_columns] = data[decimal_columns].apply(pd.to_numeric, errors='coerce')

# Calculate the correlation matrix
correlation_matrix = data.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                                                     Total greenhouse gas emissions year 2015  \
# Total greenhouse gas emissions year 2015                                            1.000000
# Total greenhouse gas emissions year 2020                                            0.999360
# Carbon dioxide emissions year 2015                                                  0.998947
# Carbon dioxide emissions year 2020                                                  0.997925
# Methane emissions year 2015                                                         0.954985
# Methane emissions year 2020                                                         0.956362
# Nitrous oxide emissions year 2015                                                   0.975655
# Nitrous oxide emissions year 2020                                                   0.970387
# Net energy imports(% of energy use) year 1990                                       0.014874
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt



# Calculate the correlation matrix
correlation_matrix = data.corr()

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# <ipython-input-54-eccebfc36c75>:9: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %% [markdown]
# Time Series Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import numpy as np

# Load the dataset
file_path = 'final_merged_data.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Convert relevant columns to numeric, replacing non-numeric entries with NaN
numeric_columns = ['Total greenhouse gas emissions year 2015', 'Total greenhouse gas emissions year 2020',
                   'Carbon dioxide emissions year 2015', 'Carbon dioxide emissions year 2020',
                   'Methane emissions year 2015', 'Methane emissions year 2020',
                   'Nitrous oxide emissions year 2015', 'Nitrous oxide emissions year 2020']

for col in numeric_columns:
    data[col] = pd.to_numeric(data[col], errors='coerce')

# Filtering data for India and a few other countries for comparison
countries_of_interest = ['India', 'China', 'United States', 'Brazil', 'Germany']
comparison_data = data[data['Country'].isin(countries_of_interest)]

# Trend Analysis - Plotting Total greenhouse gas emissions for 2015 and 2020
plt.figure(figsize=(10, 6))
sns.barplot(x='Country', y='Total greenhouse gas emissions year 2020', data=comparison_data, palette="viridis")
plt.title('Total Greenhouse Gas Emissions in 2020')
plt.ylabel('Emissions (Metric Tons)')
plt.xlabel('Country')
plt.show()

# Forecasting for India
india_data = data[data['Country'] == 'India'][['Total greenhouse gas emissions year 2015', 'Total greenhouse gas emissions year 2020']]
india_data = india_data.dropna()

# Preparing the data for forecasting
india_data = india_data.T
india_data.columns = ['Emissions']
india_data['Year'] = [2015, 2020]
india_data.set_index('Year', inplace=True)

# Exponential Smoothing model
model = ExponentialSmoothing(india_data['Emissions'], trend='add', seasonal=None, seasonal_periods=None)
model_fit = model.fit()

# Forecast for the next 5 years (2025, 2030, 2035, 2040, 2045)
forecast_years = np.arange(2025, 2050, 5)
forecast = model_fit.forecast(len(forecast_years))

# Plotting the forecast
plt.figure(figsize=(10, 6))
plt.plot(india_data.index, india_data['Emissions'], label='Historical Data', marker='o')
plt.plot(forecast_years, forecast, label='Forecast', marker='x', color='red')
plt.title('Forecast of Total Greenhouse Gas Emissions for India')
plt.ylabel('Emissions (Metric Tons)')
plt.xlabel('Year')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'final_merged_data.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Convert relevant columns to numeric, replacing non-numeric entries with NaN
numeric_columns = ['Total greenhouse gas emissions year 2015', 'Total greenhouse gas emissions year 2020',
                   'Carbon dioxide emissions year 2015', 'Carbon dioxide emissions year 2020',
                   'Methane emissions year 2015', 'Methane emissions year 2020',
                   'Nitrous oxide emissions year 2015', 'Nitrous oxide emissions year 2020']

for col in numeric_columns:
    data[col] = pd.to_numeric(data[col], errors='coerce')

# Filtering data for selected countries for comparison
countries_of_interest = ['India', 'China', 'United States', 'Brazil', 'Germany']
comparison_data = data[data['Country'].isin(countries_of_interest)]

# Preparing data for a comprehensive comparison plot
# Selecting emission types and years for comparison
emission_types = {
    'Total Greenhouse Gas 2015': 'Total greenhouse gas emissions year 2015',
    'Total Greenhouse Gas 2020': 'Total greenhouse gas emissions year 2020',
    'CO2 Emissions 2015': 'Carbon dioxide emissions year 2015',
    'CO2 Emissions 2020': 'Carbon dioxide emissions year 2020',
    'Methane Emissions 2015': 'Methane emissions year 2015',
    'Methane Emissions 2020': 'Methane emissions year 2020',
    'Nitrous Oxide 2015': 'Nitrous oxide emissions year 2015',
    'Nitrous Oxide 2020': 'Nitrous oxide emissions year 2020'
}

# Melting the comparison_data to have a long-form DataFrame suitable for sns.catplot
comparison_melted = comparison_data.melt(id_vars='Country', value_vars=list(emission_types.values()),
                                         var_name='Emission Type', value_name='Emissions')

# Creating a big comparison plot
plt.figure(figsize=(18, 10))
sns.catplot(x='Country', y='Emissions', hue='Emission Type', data=comparison_melted, kind='bar', palette='viridis', height=6, aspect=2)
plt.title('Comprehensive Emissions Comparison (2015 vs 2020)')
plt.ylabel('Emissions (Metric Tons)')
plt.xlabel('Country')
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()
